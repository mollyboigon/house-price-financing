# %%
import pandas as pd

# %% [markdown]
# I import the excel file, which I retrieved from this link https://www.census.gov/construction/nrs/historical_data/index.html

# %%
df = pd.read_excel("data/pricefinc_cust.xls", skiprows = 5)
df
# Out:
#                                            Unnamed: 0  Unnamed: 1   tional1  \
# 0                                                1988    112500.0  135000.0
# 1                                                1989    120000.0  145000.0
# 2                                                1990    122900.0  147700.0
# 3                                                1991    120000.0  142400.0
# 4                                                1992    121500.0  138000.0
# 5                                                1993    126500.0  140000.0
# 6                                                1994    130000.0  145000.0
# 7                                                1995    133900.0  148500.0
# 8                                                1996    140000.0  155000.0
# 9                                                1997    146000.0  160800.0
# 10                                               1998    152500.0  167000.0
# ...

# %%
df.head(10)
# Out:
#   Median and Average Sales Price of Houses Sold by Type of Financing  \
# 0                                                NaN
# 1                                             Period
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                               1988
# 6                                               1989
# 7                                               1990
# 8                                               1991
# 9                                               1992
#
#            Unnamed: 1          Unnamed: 2 Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                 NaN                 NaN        NaN         NaN          NaN
# 1  Median Sales Price                 NaN        NaN         NaN          NaN
# 2          Total Sold  Type of Financing         NaN         NaN          NaN
# ...

# %%
df = df.rename(columns={"Median and Average Sales Price of Houses Sold by Type of Financing": "year", "Unnamed: 1": "med-price-total", "Unnamed: 2": "med-price-conv", "Unnamed: 3": "med-price-fha", "Unnamed: 4": "med-price-va", "Unnamed: 5": "med-price-rur", "Unnamed: 6": "med-price-cash", "Unnamed: 7": "av-price-total", "Unnamed: 8": "av-price-conv","Unnamed: 9": "av-price-fha","Unnamed: 10": "av-price-va", "Unnamed: 11": "av-price-rur", "Unnamed: 12": "av-price-cash"})

# %%
df
# Out:
#                                                  year     med-price-total  \
# 0                                                 NaN                 NaN
# 1                                              Period  Median Sales Price
# 2                                                 NaN          Total Sold
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                1988              112500
# 6                                                1989              120000
# 7                                                1990              122900
# 8                                                1991              120000
# 9                                                1992              121500
# 10                                               1993              126500
# 11                                               1994              130000
# ...

# %%
#iloc for deleting last two rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ty/91pvbp991kscxb696nhhm1nc0000gn/T/ipykernel_10517/1520582392.py in <module>
# ----> 1 df = df.drop(df.index[0:4], inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
type("year")
# Out:
# str

# %%
#change it into datetime
# Out:
#   File "/var/folders/ty/91pvbp991kscxb696nhhm1nc0000gn/T/ipykernel_10517/303577026.py", line 1
#     pd.to_numeric([column = "year"])
#                           ^
# SyntaxError: invalid syntax
